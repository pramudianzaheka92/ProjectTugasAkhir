# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_januari = pd.read_csv("Volume Pengangkutan Sampah Di Kali Sungai Situ Waduk Bulan Januari Tahun 2021.csv",
                          encoding="latin-1")
data_januari.head()
# Out:
#    bulan                                titik_lokasi   kecamatan   \
# 0      1       Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1      1         Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2      1     Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3      1  Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4      1           Kali / Sungai Sentiong - Jl. Timah  Johar Baru
#
#         wilayah   panjang/luas  satuan_panjang/luas  tanggal  \
# 0  Jakarta Pusat            464                   m        1
# 1  Jakarta Pusat            464                   m        1
# 2  Jakarta Pusat            464                   m        1
# 3  Jakarta Pusat            606                   m        1
# 4  Jakarta Pusat            310                   m        1
#
#   volume_sampah_perhari(m3)
# 0                         4
# 1                         4
# 2                         4
# 3                         4
# 4                         7

# %%
data_januari.tail()
# Out:
#        bulan                                      titik_lokasi   kecamatan   \
# 54338      1  Kali Cakung Drain (Jembatan Tinggi-Perbatasan ...      Cakung
# 54339      1                                   PHB Rawa Teratai      Cakung
# 54340      1                                 PHB Rawa Gelam III      Cakung
# 54341      1                                   PHB Metropos KIP      Cakung
# 54342      1                                 PHB Warung Jengkol      Cakung
#
#             wilayah   panjang/luas  satuan_panjang/luas  tanggal  \
# 54338  Jakarta Timur            800                   m       31
# 54339  Jakarta Timur            700                   m       31
# 54340  Jakarta Timur           1000                   m       31
# 54341  Jakarta Timur           1000                   m       31
# 54342  Jakarta Timur            400                   m       31
#
#       volume_sampah_perhari(m3)
# 54338                         -
# 54339                         -
# ...

# %%
# Melihat info dataset (tipe data, total record data, dll)
data_januari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54343 entries, 0 to 54342
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   bulan                      54343 non-null  int64
#  1    titik_lokasi              54343 non-null  object
#  2    kecamatan                 54343 non-null  object
#  3    wilayah                   54343 non-null  object
#  4    panjang/luas              53475 non-null  object
#  5   satuan_panjang/luas        32388 non-null  object
#  6   tanggal                    54343 non-null  int64
#  7   volume_sampah_perhari(m3)  54343 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
data_januari.isnull().sum()
# Out:
# bulan                            0
#  titik_lokasi                    0
#  kecamatan                       0
#  wilayah                         0
#  panjang/luas                  868
# satuan_panjang/luas          21955
# tanggal                          0
# volume_sampah_perhari(m3)        0
# dtype: int64

# %%
# Menghapus jarak spasi pada kolom dataset
data_januari.columns = data_januari.columns.str.replace(" ", "")

data_januari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54343 entries, 0 to 54342
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   bulan                      54343 non-null  int64
#  1   titik_lokasi               54343 non-null  object
#  2   kecamatan                  54343 non-null  object
#  3   wilayah                    54343 non-null  object
#  4   panjang/luas               53475 non-null  object
#  5   satuan_panjang/luas        32388 non-null  object
#  6   tanggal                    54343 non-null  int64
#  7   volume_sampah_perhari(m3)  54343 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
# Bar plot untuk kolom "wilayah"

plt.style.use("seaborn")
sns.countplot(x="wilayah", data=data_januari)
plt.figure(figsize=(10, 8))
plt.show()

# %%
data_januari.head(30)
# Out:
#     bulan                                       titik_lokasi      kecamatan  \
# 0       1             Kali / Sungai Sentiong - Ruas Dewi Sri     Johar Baru
# 1       1               Kali / Sungai Sentiong - Ruas Abapon     Johar Baru
# 2       1           Kali / Sungai Sentiong - JL Tanah Tinggi     Johar Baru
# 3       1        Kali / Sungai Sentiong Jl.Galur - Pombensin     Johar Baru
# 4       1                 Kali / Sungai Sentiong - Jl. Timah     Johar Baru
# 5       1                                PHB Kawi Kawi Bawah     Johar Baru
# 6       1                                      PHB Kayu Awet     Johar Baru
# 7       1                                    PHB Pulo Gundul     Johar Baru
# 8       1                               PHB Tanah Tinggi XII     Johar Baru
# 9       1                                      PHB Bala Dewa     Johar Baru
# 10      1                           PHB Percetakan Negara II     Johar Baru
# ...

# %%
# Mengapus nilai record NaN/data kosong pada kolom panjang/luas 
data_januari = data_januari.dropna(axis=0, subset=["panjang/luas"])

data_januari.isnull().sum()
# Out:
# bulan                            0
# titik_lokasi                     0
# kecamatan                        0
# wilayah                          0
# panjang/luas                     0
# satuan_panjang/luas          21087
# tanggal                          0
# volume_sampah_perhari(m3)        0
# dtype: int64

# %%
# Menghapus karakter yang berada di record kolom data
data_januari["panjang/luas"] = data_januari["panjang/luas"].str.replace(r"\D", "")

data_januari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53475 entries, 0 to 54342
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   bulan                      53475 non-null  int64
#  1   titik_lokasi               53475 non-null  object
#  2   kecamatan                  53475 non-null  object
#  3   wilayah                    53475 non-null  object
#  4   panjang/luas               53475 non-null  object
#  5   satuan_panjang/luas        32388 non-null  object
#  6   tanggal                    53475 non-null  int64
#  7   volume_sampah_perhari(m3)  53475 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.7+ MB

# %%
# Mengahapus karakter "-" di kolom "volume_sampah_perhari(m3)" dengan menggantikan nilai NaN

data_januari["volume_sampah_perhari(m3)"] = data_januari["volume_sampah_perhari(m3)"].replace("-", np.nan)
data_januari.head(30)
# Out:
#     bulan                                       titik_lokasi      kecamatan  \
# 0       1             Kali / Sungai Sentiong - Ruas Dewi Sri     Johar Baru
# 1       1               Kali / Sungai Sentiong - Ruas Abapon     Johar Baru
# 2       1           Kali / Sungai Sentiong - JL Tanah Tinggi     Johar Baru
# 3       1        Kali / Sungai Sentiong Jl.Galur - Pombensin     Johar Baru
# 4       1                 Kali / Sungai Sentiong - Jl. Timah     Johar Baru
# 5       1                                PHB Kawi Kawi Bawah     Johar Baru
# 6       1                                      PHB Kayu Awet     Johar Baru
# 7       1                                    PHB Pulo Gundul     Johar Baru
# 8       1                               PHB Tanah Tinggi XII     Johar Baru
# 9       1                                      PHB Bala Dewa     Johar Baru
# 10      1                           PHB Percetakan Negara II     Johar Baru
# ...

# %%
# Mengubah tipe data pada kolom "panjang/luas" dari string menjadi float
data_januari[["panjang/luas"]] = data_januari[["panjang/luas"]].apply(pd.to_numeric)
data_januari.head()
# Out:
#    bulan                                 titik_lokasi   kecamatan  \
# 0      1       Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1      1         Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2      1     Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3      1  Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4      1           Kali / Sungai Sentiong - Jl. Timah  Johar Baru
#
#          wilayah  panjang/luas satuan_panjang/luas  tanggal  \
# 0  Jakarta Pusat         464.0                   m        1
# 1  Jakarta Pusat         464.0                   m        1
# 2  Jakarta Pusat         464.0                   m        1
# 3  Jakarta Pusat         606.0                   m        1
# 4  Jakarta Pusat         310.0                   m        1
#
#   volume_sampah_perhari(m3)
# 0                         4
# 1                         4
# 2                         4
# 3                         4
# 4                         7

# %%
# Bar plot untuk kolom "kecamatan"

plt.xticks(rotation=90)
sns.countplot(x="kecamatan", data=data_januari)
plt.figure(figsize=(10, 10))
plt.show()

# %%
data_januari.isnull().sum()
# Out:
# bulan                            0
# titik_lokasi                     0
# kecamatan                        0
# wilayah                          0
# panjang/luas                    31
# satuan_panjang/luas          21087
# tanggal                          0
# volume_sampah_perhari(m3)    15596
# dtype: int64

# %%
# Mengubah tipe data pada kolom "volume_sampah_perhari(m3)" dari string menjadi float
data_januari["volume_sampah_perhari(m3)"] = pd.to_numeric(data_januari["volume_sampah_perhari(m3)"], errors="coerce")
data_januari.head()
# Out:
#    bulan                                 titik_lokasi   kecamatan  \
# 0      1       Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1      1         Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2      1     Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3      1  Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4      1           Kali / Sungai Sentiong - Jl. Timah  Johar Baru
#
#          wilayah  panjang/luas satuan_panjang/luas  tanggal  \
# 0  Jakarta Pusat         464.0                   m        1
# 1  Jakarta Pusat         464.0                   m        1
# 2  Jakarta Pusat         464.0                   m        1
# 3  Jakarta Pusat         606.0                   m        1
# 4  Jakarta Pusat         310.0                   m        1
#
#    volume_sampah_perhari(m3)
# 0                        4.0
# 1                        4.0
# 2                        4.0
# 3                        4.0
# 4                        7.0

# %%
# Mengisi nilai NaN yang ada disetiap kolom menjadi nilai rata-rata

mean = data_januari.mean()
data_januari = data_januari.replace(np.nan, mean)
data_januari.head()
# Out:
#    bulan                                 titik_lokasi   kecamatan  \
# 0      1       Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1      1         Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2      1     Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3      1  Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4      1           Kali / Sungai Sentiong - Jl. Timah  Johar Baru
#
#          wilayah  panjang/luas satuan_panjang/luas  tanggal  \
# 0  Jakarta Pusat         464.0                   m        1
# 1  Jakarta Pusat         464.0                   m        1
# 2  Jakarta Pusat         464.0                   m        1
# 3  Jakarta Pusat         606.0                   m        1
# 4  Jakarta Pusat         310.0                   m        1
#
#    volume_sampah_perhari(m3)
# 0                        4.0
# 1                        4.0
# 2                        4.0
# 3                        4.0
# 4                        7.0

# %%
"""
Mengubah tipe data pada kolom "panjang/luas" dan "volume_sampah_perhari(m3)" dari float menjadi integer
"""

data_januari["panjang/luas"] = data_januari["panjang/luas"].astype(int)
data_januari["volume_sampah_perhari(m3)"] = data_januari["volume_sampah_perhari(m3)"].astype(int)

data_januari.head()
# Out:
#    bulan                                 titik_lokasi   kecamatan  \
# 0      1       Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1      1         Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2      1     Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3      1  Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4      1           Kali / Sungai Sentiong - Jl. Timah  Johar Baru
#
#          wilayah  panjang/luas satuan_panjang/luas  tanggal  \
# 0  Jakarta Pusat           464                   m        1
# 1  Jakarta Pusat           464                   m        1
# 2  Jakarta Pusat           464                   m        1
# 3  Jakarta Pusat           606                   m        1
# 4  Jakarta Pusat           310                   m        1
#
#    volume_sampah_perhari(m3)
# 0                          4
# 1                          4
# 2                          4
# 3                          4
# 4                          7

# %%
data_januari.isnull().sum()
# Out:
# bulan                            0
# titik_lokasi                     0
# kecamatan                        0
# wilayah                          0
# panjang/luas                     0
# satuan_panjang/luas          21087
# tanggal                          0
# volume_sampah_perhari(m3)        0
# dtype: int64

# %%
data_januari.describe()
# Out:
#          bulan   panjang/luas       tanggal  volume_sampah_perhari(m3)
# count  53475.0   53475.000000  53475.000000               53475.000000
# mean       1.0    9445.186255     16.000000                   4.077475
# std        0.0   30649.731895      8.944356                   4.405520
# min        1.0       0.000000      1.000000                   0.000000
# 25%        1.0     500.000000      8.000000                   1.000000
# 50%        1.0    1000.000000     16.000000                   4.000000
# 75%        1.0    2000.000000     24.000000                   4.000000
# max        1.0  350070.000000     31.000000                 152.000000

# %%
data_januari.head(30)
# Out:
#     bulan                                       titik_lokasi      kecamatan  \
# 0       1             Kali / Sungai Sentiong - Ruas Dewi Sri     Johar Baru
# 1       1               Kali / Sungai Sentiong - Ruas Abapon     Johar Baru
# 2       1           Kali / Sungai Sentiong - JL Tanah Tinggi     Johar Baru
# 3       1        Kali / Sungai Sentiong Jl.Galur - Pombensin     Johar Baru
# 4       1                 Kali / Sungai Sentiong - Jl. Timah     Johar Baru
# 5       1                                PHB Kawi Kawi Bawah     Johar Baru
# 6       1                                      PHB Kayu Awet     Johar Baru
# 7       1                                    PHB Pulo Gundul     Johar Baru
# 8       1                               PHB Tanah Tinggi XII     Johar Baru
# 9       1                                      PHB Bala Dewa     Johar Baru
# 10      1                           PHB Percetakan Negara II     Johar Baru
# ...
